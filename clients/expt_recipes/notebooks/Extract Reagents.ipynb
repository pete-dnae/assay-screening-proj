# %%
from urllib.request import Request, urlopen
import json
from pandas.io.json import json_normalize

# %%
request = Request("http://assay-screening.herokuapp.com/api/reagents/")
request.add_header('Authorization', 'JWT eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJleHAiOjE1MzAxMDEzMzQsInVzZXJfaWQiOjEsInVzZXJuYW1lIjoiYWRtaW4iLCJvcmlnX2lhdCI6MTUzMDA5NzczNCwiZW1haWwiOiJwcmFzYW5uYS5nbmFuYXJhakBkbmFlLmNvbSJ9.CWaudUmWSDB6y3PGbAcONW8lmns8I8gEZTjBmo9SwJY')
resp = urlopen(request)

byteString = resp.read()
json_data = json.loads(byteString)

# %%
dataFrame = json_normalize(json_data)

# %%
import pandas as pd

# %%
metaData = pd.read_excel(r'\\smb.dnae.com\dnae\sequencing\integrated_seq\Experiments\A81_Assay redesign\02_Primers\20180122 target_length.xlsx')

# %%
def find_amplicon_length(target):
    try:
        amplicon_length = metaData[metaData.target==target]['length'].values[0]
    except:
        print(target)
        return None
    return int(amplicon_length)

# %%
target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-80fb1dd0b208> in <module>()
# ----> 1 target
#
# NameError: name 'target' is not defined

# %%
dataFrame['opaque_json_payload'] = dataFrame[dataFrame.category=='assay']['name'].apply(find_amplicon_length)
# Out:
# AMR_IMP_x.1_IMP04_IMP24
# AMR_IMP_x.2_IMP10_IMP17
# AMR_IMP_x.3_IMP10_IMP18
# AMR_IMP_x.4_IMP12_IMP17
# AMR_IMP_x.5_IMP12_IMP18
# AMR_IMP_x.6_IMP12_IMP19
# AMR_IMP_x.7_IMP13_IMP17
# AMR_IMP_x.8_IMP13_IMP18
# AMR_IMP_x.9_IMP13_IMP19
# AMR_IMP_1.x_IMP22_IMP11
# AMR_IMP_2.x_IMP23_IMP25

# %%
dataFrame['opaque_json_payload']=dataFrame['opaque_json_payload'].fillna('null')

# %%
dataFrame.to_csv(r'C:\Users\Prasanna.Gnanaraj\Documents\assay-screening\app\model_builders\customers-seed-data\reagents.csv')

# %%
json.loads("{\"amplicon_length\": \"384\"}")
# Out:
# {'amplicon_length': '384'}

# %%
metaData
# Out:
#                            target                         F  \
# 0        Ab_oxa51_1.x_Aba10_Aba04    Abau_OXA51_1_40_23_PAf
# 1        Ab_oxa51_2.x_Aba08_Aba02   Abau_OXA51_1_142_23_PAf
# 2        Ab_oxa51_x.1_Aba09_Aba05    Abau_OXA51_1_68_23_IDf
# 3        Ab_oxa51_x.2_Aba06_Aba03   Abau_OXA51_1_169_22_IDf
# 4        Ab_oxa51_x.3_Aba07_Aba03   Abau_OXA51_1_169_21_IDf
# 5         Ab_pgaD_1.x_Aba17_Aba20     Abau_pgaD_1_58_23_PAf
# 6         Ab_pgaD_2.x_Aba26_Aba28     Abau_pgaD_1_51_23_PAf
# 7         Ab_pgaD_3.x_Aba27_Aba29     Abau_pgaD_1_50_23_PAf
# 8         Ab_pgaD_x.1_Aba18_Aba19    Abau_pgaD_1_138_26_IDf
# 9        Ab_pgaD_x.10_Aba38_Aba42    Abau_pgaD_1_162_23_IDf
# 10       Ab_pgaD_x.10_Aba43_Aba42  Abau_pgaD_1_162_23_IDfdg
# 11       Ab_pgaD_x.11_Aba39_Aba42    Abau_pgaD_1_192_24_IDf
# 12       Ab_pgaD_x.11_Aba44_Aba42  Abau_pgaD_1_192_24_IDfdg
# 13       Ab_pgaD_x.12_Aba38_Aba35    Abau_pgaD_1_162_23_IDf
# 14       Ab_pgaD_x.12_Aba43_Aba35  Abau_pgaD_1_162_23_IDfdg
# 15       Ab_pgaD_x.13_Aba39_Aba35    Abau_pgaD_1_192_24_IDf
# 16       Ab_pgaD_x.13_Aba44_Aba35  Abau_pgaD_1_192_24_IDfdg
# 17        Ab_pgaD_x.2_Aba25_Aba19    Abau_pgaD_1_137_26_IDf
# 18        Ab_pgaD_x.3_Aba37_Aba40    Abau_pgaD_1_121_23_IDf
# 19        Ab_pgaD_x.4_Aba38_Aba40    Abau_pgaD_1_162_23_IDf
# 20        Ab_pgaD_x.4_Aba43_Aba40  Abau_pgaD_1_162_23_IDfdg
# 21        Ab_pgaD_x.5_Aba39_Aba40    Abau_pgaD_1_192_24_IDf
# 22        Ab_pgaD_x.5_Aba44_Aba40  Abau_pgaD_1_192_24_IDfdg
# 23        Ab_pgaD_x.6_Aba37_Aba41    Abau_pgaD_1_121_23_IDf
# 24        Ab_pgaD_x.7_Aba38_Aba41    Abau_pgaD_1_162_23_IDf
# 25        Ab_pgaD_x.7_Aba43_Aba41  Abau_pgaD_1_162_23_IDfdg
# 26        Ab_pgaD_x.8_Aba39_Aba41    Abau_pgaD_1_192_24_IDf
# 27        Ab_pgaD_x.8_Aba44_Aba41  Abau_pgaD_1_192_24_IDfdg
# 28        Ab_pgaD_x.9_Aba37_Aba42    Abau_pgaD_1_121_23_IDf
# 29        Ab_vim1_4.x_VIM31_VIM37     AMR_vim1_1_302_20_PAf
# ...                           ...                       ...
# 1206  AMR_ctxm40_14.x_CTX46_CTX54   AMR_ctxm40_1_442_20_PAf
# 1207    AMR_ctxm2_x.8_CTX56_CTX59    AMR_ctxm2_1_107_20_IDf
# 1208    AMR_ctxm2_x.9_CTX57_CTX59    AMR_ctxm2_1_152_21_IDf
# 1209   AMR_ctxm2_15.x_CTX55_CTX60     AMR_ctxm2_1_54_20_PAf
# 1210   AMR_ctxm2_x.10_CTX62_CTX64    AMR_ctxm2_1_632_20_IDf
# 1211   AMR_ctxm2_16.x_CTX61_CTX65    AMR_ctxm2_1_569_21_PAf
# 1212   AMR_ctxm9_x.11_CTX67_CTX69    AMR_ctxm9_1_323_21_IDf
# 1213   AMR_ctxm9_17.x_CTX66_CTX70    AMR_ctxm9_1_253_21_PAf
# 1214  AMR_ctxm15_x.12_CTX73_CTX75   AMR_ctxm15_1_332_20_IDf
# 1215  AMR_ctxm15_18.x_CTX71_CTX76   AMR_ctxm15_1_214_21_PAf
# 1216  AMR_ctxm15_19.x_CTX72_CTX76   AMR_ctxm15_1_261_21_PAf
# 1217  AMR_ctxm15_x.13_CTX78_CTX80   AMR_ctxm15_1_587_21_IDf
# 1218  AMR_ctxm15_20.x_CTX77_CTX81   AMR_ctxm15_1_503_20_PAf
# 1219  AMR_ctxm40_x.14_CTX83_CTX85   AMR_ctxm40_1_249_22_IDf
# 1220  AMR_ctxm40_21.x_CTX82_CTX86   AMR_ctxm40_1_209_19_PAf
# 1221  AMR_ctxm40_22.x_CTX82_CTX87   AMR_ctxm40_1_209_19_PAf
# 1222   AMR_ctxm_x.15_CTX95_CTX100     AMR_ctxm_1_209_22_IDf
# 1223    AMR_ctxm_23.x_CTX98_CTX99    AMR_ctxm_1_153_20_PAfS
# 1224  AMR_ctxm40_24.x_CTX88_CTX54  AMR_ctxm40_1_442_20_PAf1
# 1225          AMR_IMP_1_92_25_IDf     AMR_IMP_1_267_24_IDrS
# 1226         AMR_IMP_1_303_21_IDf      AMR_IMP_1_479_23_IDr
# 1227         AMR_IMP_1_303_21_IDf      AMR_IMP_1_481_23_IDr
# 1228         AMR_IMP_1_329_24_IDf      AMR_IMP_1_479_23_IDr
# 1229         AMR_IMP_1_329_24_IDf      AMR_IMP_1_481_23_IDr
# 1230         AMR_IMP_1_329_24_IDf      AMR_IMP_1_518_23_IDr
# 1231         AMR_IMP_1_333_23_IDf      AMR_IMP_1_479_23_IDr
# 1232         AMR_IMP_1_333_23_IDf      AMR_IMP_1_481_23_IDr
# 1233         AMR_IMP_1_333_23_IDf      AMR_IMP_1_518_23_IDr
# 1234         AMR_IMP_1_27_23_PAfS      AMR_IMP_1_312_24_PAr
# 1235        AMR_IMP_1_183_24_PAfS     AMR_IMP_1_563_22_PArS
#
#                              R  length  order Exp no of test
# 0      Abau_OXA51_1_322_22_PAr     304      1            NaN
# 1      Abau_OXA51_1_426_23_PAr     307      2            NaN
# 2      Abau_OXA51_1_253_22_IDr     207      3            NaN
# 3     Abau_OXA51_1_368_21_IDr2     220      4            NaN
# 4     Abau_OXA51_1_368_21_IDr2     220      5            NaN
# 5       Abau_pgaD_1_389_22_PAr     353      6            NaN
# 6       Abau_pgaD_1_431_23_PAr     403      7            NaN
# 7       Abau_pgaD_1_431_22_PAr     403      8            NaN
# 8       Abau_pgaD_1_332_23_IDr     217      9            NaN
# 9       Abau_pgaD_1_364_23_IDr     225     10            NaN
# 10      Abau_pgaD_1_364_23_IDr     225     11            NaN
# 11      Abau_pgaD_1_364_23_IDr     195     12            NaN
# 12      Abau_pgaD_1_364_23_IDr     195     13            NaN
# 13      Abau_pgaD_1_431_23_PAr     292     14            NaN
# 14      Abau_pgaD_1_431_23_PAr     292     15            NaN
# 15      Abau_pgaD_1_431_23_PAr     262     16            NaN
# 16      Abau_pgaD_1_431_23_PAr     262     17            NaN
# 17      Abau_pgaD_1_332_23_IDr     218     18            NaN
# 18      Abau_pgaD_1_346_23_IDr     248     19            NaN
# 19      Abau_pgaD_1_346_23_IDr     207     20            NaN
# 20      Abau_pgaD_1_346_23_IDr     207     21            NaN
# 21      Abau_pgaD_1_346_23_IDr     177     22            NaN
# 22      Abau_pgaD_1_346_23_IDr     177     23            NaN
# 23      Abau_pgaD_1_361_23_IDr     263     24            NaN
# 24      Abau_pgaD_1_361_23_IDr     222     25            NaN
# 25      Abau_pgaD_1_361_23_IDr     222     26            NaN
# 26      Abau_pgaD_1_361_23_IDr     192     27            NaN
# 27      Abau_pgaD_1_361_23_IDr     192     28            NaN
# 28      Abau_pgaD_1_364_23_IDr     266     29            NaN
# 29       AMR_vim1_1_602_21_PAr     321     30            NaN
# ...                        ...     ...    ...            ...
# 1206  AMR_ctxm40_1_852_20_PArS     430   1189            NaN
# 1207    AMR_ctxm2_1_319_21_IDr     233   1218            NaN
# 1208    AMR_ctxm2_1_319_21_IDr     188   1219            NaN
# 1209    AMR_ctxm2_1_416_21_PAr     383   1220            NaN
# 1210    AMR_ctxm2_1_820_21_IDr     209   1221            NaN
# 1211    AMR_ctxm2_1_855_21_PAr     307   1222            NaN
# 1212    AMR_ctxm9_1_507_20_IDr     204   1223            NaN
# 1213    AMR_ctxm9_1_644_19_PAr     410   1224            NaN
# 1214   AMR_ctxm15_1_483_21_IDr     172   1225            NaN
# 1215   AMR_ctxm15_1_537_20_PAr     343   1226            NaN
# 1216   AMR_ctxm15_1_537_20_PAr     296   1227            NaN
# 1217   AMR_ctxm15_1_740_21_IDr     174   1228            NaN
# 1218   AMR_ctxm15_1_783_21_PAr     301   1229            NaN
# 1219   AMR_ctxm40_1_447_20_IDr     218   1230            NaN
# 1220   AMR_ctxm40_1_487_18_PAr     296   1231            NaN
# 1221   AMR_ctxm40_1_611_20_PAr     422   1232            NaN
# 1222    AMR_ctxm_1_412_22_IDrS     225   1233            NaN
# 1223    AMR_ctxm_1_584_19_PArS     450   1234            NaN
# 1224  AMR_ctxm40_1_852_20_PArS     430   1235            NaN
# 1225   AMR_IMP_x.1_IMP04_IMP24     199   1236            NaN
# 1226   AMR_IMP_x.2_IMP10_IMP17     199   1237            NaN
# 1227   AMR_IMP_x.3_IMP10_IMP18     201   1238            NaN
# 1228   AMR_IMP_x.4_IMP12_IMP17     173   1239            NaN
# 1229   AMR_IMP_x.5_IMP12_IMP18     175   1240            NaN
# 1230   AMR_IMP_x.6_IMP12_IMP19     212   1241            NaN
# 1231   AMR_IMP_x.7_IMP13_IMP17     169   1242            NaN
# 1232   AMR_IMP_x.8_IMP13_IMP18     171   1243            NaN
# 1233   AMR_IMP_x.9_IMP13_IMP19     208   1244            NaN
# 1234   AMR_IMP_1.x_IMP22_IMP11     309   1245            NaN
# 1235   AMR_IMP_2.x_IMP23_IMP25     402   1246            NaN
#
# [1236 rows x 6 columns]

# %%
json.loads('"{\\""amplicon_length\\"":403}"')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-96-1a36ed8bf17e> in <module>()
# ----> 1 json.loads('"{\\""amplicon_length\\"":403}"')
#
# c:\users\prasanna.gnanaraj\appdata\local\programs\python\python36\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# c:\users\prasanna.gnanaraj\appdata\local\programs\python\python36\lib\json\decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 1 column 6 (char 5)
